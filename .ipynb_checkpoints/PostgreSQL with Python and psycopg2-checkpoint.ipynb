# %% [markdown]
# # PostgreSQL with Python

# %%
import psycopg2 as pg2

# %%
conn = pg2.connect(database='dvdrental',user='postgres',password='Flaming4')

# %%
cur = conn.cursor()

# %%
cur.execute('SELECT * FROM payment')

# %%
cur.fetchone()
# Out:
# (17503,
#  341,
#  2,
#  1520,
#  Decimal('7.99'),
#  datetime.datetime(2007, 2, 15, 22, 25, 46, 996577))

# %%
data = cur.fetchmany(10)

# %%
data[0][4]
# Out:
# Decimal('0.99')

# %%
conn.close()
